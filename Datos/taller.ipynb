# %%
import pandas as pd

# %%
df=pd.read_csv("exportaciones.csv")
print("===============Vista inicial del DataFrame===================")
display(df.head())
# Out:
# ===============Vista inicial del DataFrame===================
#                     fecha          fecha de corte  \
# 0  03/31/2000 12:00:00 AM  10/01/2021 12:00:00 AM
# 1  06/30/2000 12:00:00 AM  10/01/2021 12:00:00 AM
# 2  09/30/2000 12:00:00 AM  10/01/2021 12:00:00 AM
# 3  12/31/2000 12:00:00 AM  10/01/2021 12:00:00 AM
# 4  03/31/2001 12:00:00 AM  10/01/2021 12:00:00 AM
#
#    Valor exportaciones totales bienes  Valor exportaciones NME  \
# 0                                3119                     1575
# 1                                3187                     1702
# 2                                3450                     1927
# 3                                3403                     1869
# 4                                2984                     1704
#
#    exportaciones de servicios  \
# 0                         468
# 1                         498
# 2                         532
# 3                         564
# 4                         514
#
# ...

# %%
df.count()
# Out:
# fecha                                                                                                                       101
# fecha de corte                                                                                                              101
# Valor exportaciones totales bienes                                                                                          101
# Valor exportaciones NME                                                                                                     101
# exportaciones de servicios                                                                                                  101
# Valor exportaciones NME + exportaciones de servicios                                                                        101
# Valor de exportaciones totales bienes + exportaciones de servicios                                                          101
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 8 columns):
#  #   Column                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                    --------------  -----
#  0   fecha                                                                                                                     101 non-null    object
#  1   fecha de corte                                                                                                            101 non-null    object
#  2   Valor exportaciones totales bienes                                                                                        101 non-null    int64
# ...

# %%
display(df.describe())
# Out:
#        Valor exportaciones totales bienes  Valor exportaciones NME  \
# count                          101.000000               101.000000
# mean                          9022.059406              3626.831683
# std                           3885.092696              1098.593319
# min                           2749.000000              1575.000000
# 25%                           6123.000000              3102.000000
# 50%                           9099.000000              3781.000000
# 75%                          12279.000000              4172.000000
# max                          15621.000000              6140.000000
#
#        exportaciones de servicios  \
# count                  101.000000
# mean                  1825.811881
# std                   1125.644124
# min                    429.000000
# 25%                    896.000000
# 50%                   1710.000000
# 75%                   2343.000000
# max                   4762.000000
#
# ...
